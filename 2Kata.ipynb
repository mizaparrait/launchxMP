# %% [markdown]
# # Crear un Entorno Virtual

# %% [markdown]
# C:\Users\iturr\workspace\launchx\katasMP>py -3 -m venv test
#
# C:\Users\iturr\workspace\launchx\katasMP>env\Scripts\activate
# El sistema no puede encontrar la ruta especificada.
#
# C:\Users\iturr\workspace\launchx\katasMP>test\Scripts\activate
#
# (test) C:\Users\iturr\workspace\launchx\katasMP>pip freeze
#
# (test) C:\Users\iturr\workspace\launchx\katasMP>pip install python-dateutil
# Collecting python-dateutil
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting six>=1.5
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Installing collected packages: six, python-dateutil
# Successfully installed python-dateutil-2.8.2 six-1.16.0
# WARNING: You are using pip version 21.2.4; however, version 22.0.3 is available.
# You should consider upgrading via the 'C:\Users\iturr\workspace\launchx\katasMP\test\Scripts\python.exe -m pip install --upgrade pip' command.
#
# (test) C:\Users\iturr\workspace\launchx\katasMP>pip freezepython-dateutil==2.8.2
# six==1.16.0
#
# (test) C:\Users\iturr\workspace\launchx\katasMP>deactivate
