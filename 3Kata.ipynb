# %% [markdown]
# # Problema No. 1 - ALERTA DE ASTEROIDE

# %%
asteroide = 49
if asteroide > 25:
    print('¡Alerta, Un asteroide esta muy cerca de la Tierra!')
else:
    print('False Alarma, era un simulacro.')
# Out:
# ¡Alerta! ¡Un asteroide se acerca a velocidades peligrosas!

# %% [markdown]
# # Problema No.2 - VARIABLE PARA UN ASTEROIDE

# %%
asteroide = 19
if asteroide > 20:
    print('El asteroide esta emitiendo una luz!')
elif asteroide == 20:
    print('LEl asteroide esta emitiendo una luz!')
else:
    print('No esta emitiendo luz')
# Out:
# ¡Nada que ver aquí!

# %% [markdown]
# # Problema No.3 - VELOCIDAD Y TAMAÑO DE UN ASTEROIDE

# %%
velocidad_asteroide = 25
tamano_asteroide = 40
if velocidad_asteroide > 25 and tamano_asteroide > 25:
    print('¡Alerta, Un asteroide esta muy cerca de la Tierra!')
elif velocidad_asteroide >= 20:
    print('El asteroide esta emitiendo una luz!')
elif tamano_asteroide < 25:
    print('No esta emitiendo luz')
else:
    print('No hay nada.')
# Out:
# Look up! ¡Hay una luz mágica en el cielo!
